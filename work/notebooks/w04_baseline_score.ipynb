# %% [markdown]
# # ML-07 — Baseline Action Score
#
# **Scope:** bundled anonymized starter slice (30,000 content items across 32 pseudonymized clients).

# %% [markdown]
# ## 1. Rule and reasons
#
# The transparent rule prioritizes pages that are visible (≥300 impressions), stale (≥180 days since update), have low CTR (≤1%), or sit on pages two to three. Reason codes state which condition contributed.
#
# ## 2. Top-20 review
#
# The preview is deliberately public-safe: no page IDs, titles, clients, URLs, or queries. Manual review must assess topical relevance, business value, correctness, and whether a content change is warranted.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / 'data').exists(): ROOT = ROOT.parent.parent
sys.path.insert(0, str(ROOT / 'work' / 'scripts'))
from sample_capstone import *
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
df=baseline_score(load_frame())
train,test=split_frame(df)
print({'test_rows':len(test),'base_rate':round(test.is_declining_label.mean(),3),'baseline_precision_at_20':round(precision_at_k(test.is_declining_label,test.baseline_score,20),3),'baseline_precision_at_50':round(precision_at_k(test.is_declining_label,test.baseline_score,50),3)})
top=test.sort_values('baseline_score',ascending=False)[['baseline_score','baseline_reason','impressions_90d','ctr','avg_position','days_since_last_update']].head(20)
top
# Out:
# {'test_rows': 7115, 'base_rate': np.float64(0.517), 'baseline_precision_at_20': 0.65, 'baseline_precision_at_50': 0.52}
#        baseline_score        baseline_reason  impressions_90d   ctr  \
# 11630              85  visible_stale_low_ctr              545  0.18
# 8506               85  visible_stale_low_ctr              371  0.54
# 3507               70  visible_stale_low_ctr              533  0.00
# 3651               70  visible_stale_low_ctr              429  0.00
# 22872              70  visible_stale_low_ctr             1408  0.28
# 140                40        visible_low_ctr              303  0.00
# 29990              40        visible_low_ctr             2542  0.16
# 26                 40        visible_low_ctr             2426  0.12
# 29991              40        visible_low_ctr              487  0.00
# 0                  40        visible_low_ctr             3803  0.76
# 14333              40        visible_low_ctr             5805  0.43
# 14392              40        visible_low_ctr              420  0.24
# 23351              40        visible_low_ctr             2449  0.24
# 5573               40        visible_low_ctr             2729  0.04
# 5586               40        visible_low_ctr              709  0.00
# 5589               40        visible_low_ctr              468  0.21
# 5712               40        visible_low_ctr             3447  0.55
# 5714               40        visible_low_ctr              349  0.57
# 5723               40        visible_low_ctr            13590  0.23
# 5730               40        visible_low_ctr              742  0.00
#
#        avg_position  days_since_last_update
# 11630          17.8                     183
# 8506           16.7                     183
# 3507           48.0                     183
# 3651            9.0                     183
# 22872           7.8                     183
# 140            17.0                      13
# 29990          22.5                      14
# 26             30.0                      13
# 29991          19.0                      13
# 0              10.6                      20
# 14333          16.8                      25
# 14392          10.2                      22
# 23351          20.0                      13
# 5573           13.3                      13
# 5586           10.4                      20
# 5589           13.2                      89
# 5712           10.2                      14
# 5714           12.4                      20
# 5723           10.6                      25
# 5730           16.7                      13

# %% [markdown]
# ## Self-check
#
# - [x] Sections contain markdown reasoning and executable code.
# - [x] No client names, URLs, private queries, or credentials.
# - [x] Claims are observed, directional, and decision-support only.
