# %% [markdown]
# # ML-05 — Feature Vector and Leakage Check
#
# **Scope:** bundled anonymized starter slice (30,000 content items across 32 pseudonymized clients).

# %% [markdown]
# ## 1. Feature vector
#
# Numeric features use median imputation; categorical features use most-frequent imputation and one-hot encoding. `has_keyword_context` exposes systematic missingness explicitly rather than silently treating it as zero.
#
# ## 2. Leakage hunt
#
# The label is built from `trend_direction`, itself derived from `trend_pct`; both are excluded. IDs are used only for the grouped split. No product scores or flags are used.
#
# ## 3. Exclusions
#
# `provider_used` and `model_used` are not used: they are not necessary for the editorial decision and could encode collection practices rather than a generalizable signal.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / 'data').exists(): ROOT = ROOT.parent.parent
sys.path.insert(0, str(ROOT / 'work' / 'scripts'))
from sample_capstone import *
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
df=load_frame(); numeric,categorical=feature_columns()
print('numeric:', numeric)
print('categorical:', categorical)
print('intersects label inputs:', set(numeric+categorical).intersection({'trend_direction','trend_pct'}))
print('intersects identifiers:', set(numeric+categorical).intersection({'content_id','client_id'}))
# Out:
# numeric: ['search_volume', 'competition', 'cpc', 'word_count', 'char_count', 'content_age_days', 'days_since_last_update', 'impressions_90d', 'clicks_90d', 'sessions_90d', 'engagement_rate', 'ctr', 'avg_position', 'days_with_impressions', 'days_with_sessions', 'scroll_rate', 'log_impressions_90d', 'log_sessions_90d', 'has_keyword_context']
# categorical: ['content_type', 'main_intent', 'competition_level', 'freshness_tier']
# intersects label inputs: set()
# intersects identifiers: set()

# %% [markdown]
# ## Self-check
#
# - [x] Sections contain markdown reasoning and executable code.
# - [x] No client names, URLs, private queries, or credentials.
# - [x] Claims are observed, directional, and decision-support only.
