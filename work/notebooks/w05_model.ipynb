# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# **Scope:** bundled anonymized starter slice (30,000 content items across 32 pseudonymized clients).

# %% [markdown]
# ## 1. Method and split
#
# Logistic regression is the readable comparator; random forest captures non-linear interactions. The held-out test set contains entire unseen pseudonymous clients, preventing row-level client memorization.
#
# ## 2. Honest comparison
#
# Every method is evaluated on the same client holdout and with the same Precision@K metric as the frozen baseline.
#
# ## 3. Interpretation
#
# Feature importance must be inspected for plausibility. Strong performance is not evidence of causality.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
if not (ROOT / 'data').exists(): ROOT = ROOT.parent.parent
sys.path.insert(0, str(ROOT / 'work' / 'scripts'))
from sample_capstone import *
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
metrics,split,test=run_models()
print(split)
metrics.round(3)
print('\nLargest model-score errors (public-safe feature view):')
test.assign(error=(test.is_declining_label-test.model_probability).abs()).sort_values('error',ascending=False)[['is_declining_label','model_probability','impressions_90d','ctr','avg_position','days_since_last_update']].head(10)
# Out:
# {'test_rows': 7115, 'test_clients': 8, 'train_clients': 24}
#
# Largest model-score errors (public-safe feature view):
#        is_declining_label  model_probability  impressions_90d   ctr  \
# 21819                   1           0.007205           463103  0.41
# 26844                   1           0.007832           509252  0.15
# 6653                    1           0.008835           517715  0.14
# 21565                   1           0.024260           309192  0.87
# 26614                   0           0.935600              290  0.00
# 27487                   1           0.069113                6  0.00
# 10175                   0           0.930792              235  0.85
# 8016                    0           0.913865             2164  0.23
# 17602                   0           0.904619             4650  0.09
# 24849                   1           0.097501               17  0.00
#
#        avg_position  days_since_last_update
# 21819           2.3                      20
# 26844           2.5                      20
# 6653            4.2                     104
# 21565           2.0                     104
# 26614           5.9                      20
# 27487          29.7                      20
# 10175          31.0                      20
# 8016            8.1                      20
# 17602          28.5                      20
# 24849           5.2                      20

# %% [markdown]
# ## Self-check
#
# - [x] Sections contain markdown reasoning and executable code.
# - [x] No client names, URLs, private queries, or credentials.
# - [x] Claims are observed, directional, and decision-support only.
